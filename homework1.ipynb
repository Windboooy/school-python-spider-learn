# %% [markdown]
# # 利用bs4爬取网页元素

# %% [markdown]
# ## 案例

# %%
from bs4 import BeautifulSoup
import requests
response = requests.get("https://www.sdpei.edu.cn/")
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
